# %% [markdown]
# # Taller 05
#
# Estudiante: Anthony Alangasí
#
# Grupo: GR1CC
#
# Fecha: 15/12/2025

# %% [markdown]
# Enlace al repositorio de Github: https://github.com/AnthoAl/Numeric-Methods/blob/master/Taller5_IIB/Taller_05.ipynb

# %% [markdown]
# ## Mínimos cuadrados
#
# A) Interpole los puntos:
#
# $p1 = (5.4, 3.2)$
#
# $p2_i = (9.5, 0.7)$
#
# $p3 = (12.3, -3.6)$

# %%
def func_pre(x):
    return -0.9578*x + 8.584

from matplotlib.lines import lineStyles
import numpy as np
import matplotlib.pyplot as plt

x0_values = np.linspace(0, 15, 100)

y0_f = [func_pre(x) for x in x0_values]

x_puntos = [5.4, 9.5, 12.3]
y_puntos = [3.2, 0.7, -3.6]

puntos_a_etiquetar = {
    '(5.4, 3.2)': (5.4, 3.2), 
    '(9.5, 0.7)': (9.5, 0.7), 
    '(12.3, -3.6)': (12.3, -3.6)
}

plt.figure(figsize=(10, 6))

plt.plot(x0_values, y0_f, label='$P_0(x)$', color='purple', linestyle = '-')

plt.plot(
    x_puntos, 
    y_puntos, 
    color='green', 
    marker='o', 
    linestyle='',
    label='Puntos dados'
)

for label, (x, y) in puntos_a_etiquetar.items():
    plt.annotate(
        label,                      
        (x, y),                     
        textcoords="offset points",
        xytext=(0, 10),             
        ha='center',                
        fontsize=9,
        color='blue'
    )

plt.title('Gráfica Resultante Ejercicio 1')
plt.xlabel('X')
plt.ylabel('Y')
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.grid(True)
plt.ylim(-6,4)
plt.legend()
plt.show()

# %% [markdown]
# ### Comprobación de la gráfica resultante utilizando la librería

# %%
# Derivadas parciales para regresión lineal
# ####################################################################
def der_parcial_1(xs: list, ys: list) -> tuple[float, float, float]:
    """Retorna los coeficientes de la ecuación de la derivada parcial con respecto al parámetro 1 al reemplazar los valores ``xs`` y ``ys``. La ecuación es de la forma:
    c_1 * a_1 + c_0 * a_0 = c_ind


    ## Parameters

    ``xs``: lista de valores de x.

    ``ys``: lista de valores de y.

    ## Return

    ``c_1``: coeficiente del parámetro 1.

    ``c_0``: coeficiente del parámetro 0.

    ``c_ind``: coeficiente del término independiente.

    """

    # coeficiente del término independiente
    c_ind = sum(ys)

    # coeficiente del parámetro 1
    c_1 = sum(xs)

    # coeficiente del parámetro 0
    c_0 = len(xs)

    return (c_1, c_0, c_ind)


def der_parcial_0(xs: list, ys: list) -> tuple[float, float, float]:
    """Retorna los coeficientes de la ecuación de la derivada parcial con respecto al parámetro 0 al reemplazar los valores ``xs`` y ``ys``. La ecuación es de la forma:
    c_1 * a_1 + c_0 * a_0 = c_ind


    ## Parameters

    ``xs``: lista de valores de x.

    ``ys``: lista de valores de y.

    ## Return

    ``c_1``: coeficiente del parámetro 1.

    ``c_0``: coeficiente del parámetro 0.

    ``c_ind``: coeficiente del término independiente.

    """
    c_1 = 0
    c_0 = 0
    c_ind = 0
    for xi, yi in zip(xs, ys):
        # coeficiente del término independiente
        c_ind += xi * yi

        # coeficiente del parámetro 1
        c_1 += xi * xi

        # coeficiente del parámetro 0
        c_0 += xi

    return (c_1, c_0, c_ind)

# %%
from src import ajustar_min_cuadrados

# UTILICE:
m, b = ajustar_min_cuadrados(xs=[5.4, 9.5, 12.3], ys=[3.2, 0.7, -3.6], gradiente = [der_parcial_1, der_parcial_0])
print(f"m: {m}, b: {b}")
# Out:
# [12-15 20:26:16][INFO] ANTHO_A| 2025-12-15 20:26:16.892302
# [12-15 20:26:16][INFO] Se ajustarán 2 parámetros.
# m: -0.9577913091613628, b: 8.783974536396357

# %%
def func_pre(x):
    return m*x + b

from matplotlib.lines import lineStyles
import numpy as np
import matplotlib.pyplot as plt

x0_values = np.linspace(0, 15, 100)

y0_f = [func_pre(x) for x in x0_values]

x_puntos = [5.4, 9.5, 12.3]
y_puntos = [3.2, 0.7, -3.6]

puntos_a_etiquetar = {
    '(5.4, 3.2)': (5.4, 3.2), 
    '(9.5, 0.7)': (9.5, 0.7), 
    '(12.3, -3.6)': (12.3, -3.6)
}

plt.figure(figsize=(10, 6))

plt.plot(x0_values, y0_f, label='$P_0(x)$', color='purple', linestyle = '-')

plt.plot(
    x_puntos, 
    y_puntos, 
    color='green', 
    marker='o', 
    linestyle='',
    label='Puntos dados'
)

for label, (x, y) in puntos_a_etiquetar.items():
    plt.annotate(
        label,                      
        (x, y),                     
        textcoords="offset points",
        xytext=(0, 10),             
        ha='center',                
        fontsize=9,
        color='blue'
    )

plt.title('Gráfica Resultante usando la librería')
plt.xlabel('X')
plt.ylabel('Y')
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.grid(True)
plt.ylim(-6,4)
plt.legend()
plt.show()

# %% [markdown]
# ### Conjunto de puntos 1

# %%
xs = [
    3.38,
    0.35,
    2.07,
    -0.45,
    -0.55,
    -1.06,
    -2.77,
    3.08,
    -3.98,
    -5.0,
    -3.18,
    -1.96,
    2.37,
    -1.66,
    4.09,
]

ys = [
    -0.04,
    1.28,
    0.65,
    2.18,
    1.70,
    1.96,
    3.36,
    0.18,
    3.35,
    4.16,
    2.95,
    2.34,
    0.38,
    1.75,
    -1.06,
]

# %%
plt.figure(figsize=(6, 4))
plt.scatter(xs, ys, color="orange", s=100)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Data Points")
plt.grid(True, alpha=0.3)
plt.show()

# %%
from src import ajustar_min_cuadrados

m, b = ajustar_min_cuadrados(xs, ys, gradiente=[der_parcial_1, der_parcial_0])
print(f"m: {m}, b: {b}")
# Out:
# [12-15 20:26:17][INFO] Se ajustarán 2 parámetros.
# m: -0.503232585436377, b: 1.4991976183166862

# %%
plt.figure(figsize=(6, 4))

# Plot the original data points
plt.scatter(xs, ys, color="orange", label="Data points", s=20)

# Plot the fitted line
x_line = np.linspace(min(xs), max(xs), 100)
y_line = m * x_line + b
plt.plot(x_line, y_line, color="purple", label=f"y = {m:.2f}x + {b:.2f}")

plt.xlabel("x")
plt.ylabel("y")
plt.title("Linear Regression")
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# ### Conjunto de datos 2

# %%
xs = [
    3.38,
0.35,
2.07,
-0.45,
-0.56,
-1.06,
-2.78,
3.08,
-3.99,
-5.00,
-3.18,
-1.97,
2.37,
-1.67,
4.09,
-4.60,
2.68,
2.78,
-3.79,
-1.87,
]

ys = [
15.65,
-11.20,
-4.00,
18.03,
7.94,
15.32,
-4.40,
1.39,
-11.92,
-90.24,
6.92,
28.35,
-2.41,
-5.47,
35.91,
-55.53,
0.77,
4.79,
-27.05,
2.85
]

# %% [markdown]
# ### Ajuste lineal

# %%
from src import ajustar_min_cuadrados

m, b = ajustar_min_cuadrados(xs, ys, gradiente=[der_parcial_1, der_parcial_0])
print(f"m: {m}, b: {b}")
# Out:
# [12-15 20:26:17][INFO] Se ajustarán 2 parámetros.
# m: 5.686665564419458, b: -0.8375472244037535

# %%
plt.figure(figsize=(6, 4))

# Plot the original data points
plt.scatter(xs, ys, color="orange", label="Data points", s=20)

# Plot the fitted line
x_line = np.linspace(min(xs), max(xs), 100)
y_line = m * x_line + b
plt.plot(x_line, y_line, color="purple", label=f"y = {m:.2f}x + {b:.2f}")

plt.xlabel("x")
plt.ylabel("y")
plt.title("Curva de ajuste lineal")
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# ### Ajuste cúbico

# %%
# Derivadas parciales para regresión lineal
# ####################################################################
def der_parcial_3(xs: list, ys: list) -> tuple[float, float, float]:
    
    c_ind = sum(ys)

    c_3 = 0
    c_2 = 0

    for xi, yi in zip(xs, ys):

        c_3 += xi**3

        c_2 += xi**2

    c_1 = sum(xs)

    c_0 = len(xs)

    return (c_3, c_2, c_1, c_0, c_ind)

def der_parcial_2(xs: list, ys: list) -> tuple[float, float, float]:
    
    c_3 = 0
    c_2 = 0
    c_1 = 0
    c_0 = 0
    c_ind = 0
    for xi, yi in zip(xs, ys):

        c_ind += xi * yi

        c_3 += xi**4

        c_2 += xi**3

        c_1 += xi**2

        c_0 += xi

    return (c_3, c_2, c_1, c_0, c_ind)

def der_parcial_1(xs: list, ys: list) -> tuple[float, float, float]:
  
    c_3 = 0
    c_2 = 0
    c_1 = 0
    c_0 = 0
    c_ind = 0
    for xi, yi in zip(xs, ys):

        c_ind += xi**2 * yi

        c_3 += xi**5

        c_2 += xi**4

        c_1 += xi**3

        c_0 += xi**2

    return (c_3, c_2, c_1, c_0, c_ind)


def der_parcial_0(xs: list, ys: list) -> tuple[float, float, float]:
    
    c_3 = 0
    c_2 = 0
    c_1 = 0
    c_0 = 0
    c_ind = 0
    for xi, yi in zip(xs, ys):

        c_ind += xi**3 * yi

        c_3 += xi**6

        c_2 += xi**5

        c_1 += xi**4

        c_0 += xi**3

    return (c_3, c_2, c_1, c_0, c_ind)

# %%
from src import ajustar_min_cuadrados

a, b, c, d = ajustar_min_cuadrados(xs, ys, gradiente=[der_parcial_3,der_parcial_2,der_parcial_1, der_parcial_0])
print(f"a: {a}, b: {b}, c: {c}, d: {d}")
# Out:
# [12-15 20:26:17][INFO] Se ajustarán 4 parámetros.
# a: 1.044977916824699, b: 0.03132740575354229, c: -8.88066397007552, d: 2.762289919876911

# %%
plt.figure(figsize=(6, 4))

# Plot the original data points
plt.scatter(xs, ys, color="orange", label="Data points", s=20)

# Plot the fitted line
x_line = np.linspace(min(xs), max(xs), 100)
y_line = a * x_line**3 + b * x_line**2 + c * x_line + d
plt.plot(x_line, y_line, color="purple", label=f"y = {m:.2f}x + {b:.2f}")

plt.xlabel("x")
plt.ylabel("y")
plt.title("Curva de ajuste cúbico")
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()
